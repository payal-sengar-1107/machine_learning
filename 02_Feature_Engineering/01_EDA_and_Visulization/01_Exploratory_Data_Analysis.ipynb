# %% [markdown]
# # Automated Exploratory Data Analysis (EDA) Pipeline
# ### Dataset: HR Analytics - Job Change of Data Scientist

# %%
import pandas as pd

# %%
df = pd.read_csv('aug_train.csv')

# %% [markdown]
# ## 1. Shape of the Dataset(Dimensionality Audit)

# %%
df.shape
# Out:
# (19158, 14)

# %% [markdown]
# ## 2. Previewing the Ingested Data

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df.sample(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 9732          3705  city_157                   0.769   Male
# 4798         27927   city_27                   0.848   Male
# 17408        26806  city_103                   0.920   Male
# 3368         17317  city_102                   0.804   Male
# 7829          1313  city_160                   0.920   Male
#
#            relevent_experience enrolled_university education_level  \
# 9732   Has relevent experience       no_enrollment         Masters
# 4798    No relevent experience       no_enrollment         Masters
# 17408  Has relevent experience       no_enrollment         Masters
# 3368   Has relevent experience    Full time course        Graduate
# 7829   Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience company_size   company_type last_new_job  \
# 9732              STEM         14    5000-9999  Public Sector            2
# ...

# %% [markdown]
# ## 3. Data Type Inspectcion & Schema Verification

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  str
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  str
#  4   relevent_experience     19158 non-null  str
#  5   enrolled_university     18772 non-null  str
#  6   education_level         18698 non-null  str
#  7   major_discipline        16345 non-null  str
#  8   experience              19093 non-null  str
#  9   company_size            13220 non-null  str
#  10  company_type            13018 non-null  str
#  11  last_new_job            18735 non-null  str
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# dtypes: float64(2), int64(2), str(10)
# memory usage: 3.4 MB

# %% [markdown]
# ## 4. Are there any missing values

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %% [markdown]
# ## 5. Descriptive Statistical Summary

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %% [markdown]
# ## 6. Are there duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. Feature Correlation Matrix

# %%
df.corr(numeric_only=True)
# Out:
#                         enrollee_id  city_development_index  training_hours  \
# enrollee_id                1.000000               -0.040455        0.000998
# city_development_index    -0.040455                1.000000        0.001920
# training_hours             0.000998                0.001920        1.000000
# target                     0.049475               -0.341665       -0.021577
#
#                           target
# enrollee_id             0.049475
# city_development_index -0.341665
# training_hours         -0.021577
# target                  1.000000
